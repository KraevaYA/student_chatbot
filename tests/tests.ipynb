# %% [markdown]
# ## **Практическое задание "Разработка студенческого telegram чат-бота" по дисциплине "Введение в проектную деятельность".**
#
# Реализация тестовой программы для проведения модульного тестирования чат-бота.

# %% [markdown]
# Выполнение проверки на то, что все необходимые библиотеки для разработки студенческого telegram чат-бота установлены в Google Colab. В случае если библиотека отсутствует в списке установленных библиотек, то выполняется ее установка.

# %%
import importlib

required_libs = ['os', 'telegram', 'datetime', 'json', 'transliterate', 'logging']

uninstalled_libs = []
for lib in required_libs:
    try:
        importlib.import_module(lib)
        print(f"{lib} has been already installed")
    except ImportError:
        print(f"{lib} has been uninstalled")
        if (lib == "telegram"):
            lib = "python-telegram-bot[job-queue] "
        uninstalled_libs.append(lib)

if (uninstalled_libs):
    installed_command = "".join(uninstalled_libs)
    # !pip install {installed_command} -q

# %% [markdown]
# Смена рабочей директории с помощью команды chdir(). Для этого необходимо передать команде свой путь до корневого каталога, в котором содержатся исходники чат-бота. После выполнения этой команды все последующие операции с файлами и каталогами будут производиться относительно указанного каталога.

# %%
import os

practice_dir_path = # INSERT YOUR DIR
os.chdir(practice_dir_path)

# %% [markdown]
# Импорт библиотек и модулей, необходимых для тестирования чат-бота.

# %%
import logging
import json
from datetime import date

from handlers import contacts_handler, timetable_handler, tutors_info_handler, utils_handler
from config import *

# %% [markdown]
# Головной модуль

# %%
class BotTester:

    @staticmethod
    def _run_test(command: str, args: list) -> str:

        # INSERT YOUR CODE

        return obtained_response


    @staticmethod
    def _load_tests(input_file_path) -> dict:

        # INSERT YOUR CODE

        return tests


    @staticmethod
    def run_tests(test_file_path: str) -> None:

        # INSERT YOUR CODE


if __name__ == "__main__":

    test_file_path = os.path.join(PROJECT_DIR, "tests/tests_data/test_contacts.json")

    BotTester.run_tests(test_file_path)
